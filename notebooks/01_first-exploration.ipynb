# %%
# %load_ext kedro.ipython
# Out:
# [03/04/26 14:06:01] INFO     Using                                                                  ]8;id=389368;file:///Users/amadeus.portes/PythonProjects/spaceflights/emailanalyzer/.venv/lib/python3.12/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=642174;file:///Users/amadeus.portes/PythonProjects/spaceflights/emailanalyzer/.venv/lib/python3.12/site-packages/kedro/framework/project/__init__.py#269\269]8;;\
#                              '/Users/amadeus.portes/PythonProjects/spaceflights/emailanalyzer/.venv
#                              /lib/python3.12/site-packages/kedro/framework/project/rich_logging.yml
#                              ' as logging configuration.
# ...
